-- %%
SELECT TOP 5 *
FROM [lh_insurance_bronze_silver].[dbo].[dm_claim_360];

-- %%
TRUNCATE TABLE dbo.wh_claim_360;

INSERT INTO dbo.wh_claim_360
SELECT *
FROM [lh_insurance_bronze_silver].[dbo].[dm_claim_360];

-- %%
TRUNCATE TABLE dbo.wh_claim_history_timeline;

INSERT INTO dbo.wh_claim_history_timeline
SELECT *
FROM [lh_insurance_bronze_silver].[dbo].[dm_claim_history_timeline];

TRUNCATE TABLE dbo.wh_fraud_support_case;

INSERT INTO dbo.wh_fraud_support_case
SELECT *
FROM [lh_insurance_bronze_silver].[dbo].[dm_fraud_support_case];

-- %%
SELECT COUNT(*) AS row_count FROM dbo.wh_claim_360;
SELECT COUNT(*) AS row_count FROM dbo.wh_claim_history_timeline;
SELECT COUNT(*) AS row_count FROM dbo.wh_fraud_support_case;
